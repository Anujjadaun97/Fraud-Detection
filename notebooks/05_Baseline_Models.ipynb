# %% [markdown]
# # 05 Baseline Models
#
# ## 1. Objective
#
# Establish baseline performance benchmarks using standard classification algorithms on the preprocessed credit card fraud dataset.
#
# **Key Goals:**
# - Train baseline models (Logistic Regression, Decision Tree, Random Forest, XGBoost) without hyperparameter tuning.
# - Evaluate models using primary fraud metrics: PR-AUC, ROC-AUC, Recall, Precision, and F1-Score.
# - Establish a performance baseline for future comparison against imbalance handling techniques and model tuning.

# %% [markdown]
# ## 2. Import Libraries
#
# Import required machine learning models, metrics, visualization tools, and data processing libraries.

# %%
# =======================
#Data handling
#=======================

import numpy as ny  
import pandas as pd 

# =======================
# Machine Learning Models
# =======================

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# ==========================
# Model Evaluations Metrics
# ==========================
from sklearn.metrics import(
    confusion_matrix,
    classification_report,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    precision_recall_curve,
    auc
)

# ===================
# Data Visualization
# ===================

import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## 3. Load Preprocessed Data
#
# Load the preprocessed training and testing data splits from `data/processed/`.

# %% [markdown]
# ## 4. Verify Loaded Data
#
# Inspect data shapes, column types, and target class balance across training and testing sets.

# %% [markdown]
# ## 5. Baseline Experiment Setup
#
# Define standard metrics evaluation pipeline, helper functions, and tracking structures for baseline comparison.

# %% [markdown]
# ## 6. Model 1 – Logistic Regression
#
# Train and evaluate a default Logistic Regression baseline model.

# %% [markdown]
# ## 7. Model 2 – Decision Tree
#
# Train and evaluate a default Decision Tree baseline model.

# %% [markdown]
# ## 8. Model 3 – Random Forest
#
# Train and evaluate a default Random Forest baseline model.

# %% [markdown]
# ## 9. Model 4 – XGBoost
#
# Train and evaluate a default XGBoost baseline model.

# %% [markdown]
# ## 10. Baseline Model Comparison
#
# Compare evaluation results across all four baseline models using summary tables and metric visualizations (PR-AUC, ROC-AUC, Recall).

# %% [markdown]
# ## 11. Key Findings
#
# Document primary insights, model trade-offs, and baseline performance metrics.

# %% [markdown]
# ## 12. Save Results
#
# Serialize baseline performance metrics and model artifacts to `reports/` or `models/`.

# %% [markdown]
# ## 13. Conclusion
#
# Summarize baseline experimentation outcomes and transition to imbalanced learning strategies.
